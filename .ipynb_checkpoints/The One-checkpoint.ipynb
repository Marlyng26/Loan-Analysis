# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('train_data.csv')

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
target = data["Loan_Status"]

# %%
data_hot = pd.get_dummies(data, columns=['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status'], drop_first=True)

# %%
data_hot=data_hot.fillna(0)
data_hot
# Out:
#       Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0    LP001002             5849                0.0         0.0
# 1    LP001003             4583             1508.0       128.0
# 2    LP001005             3000                0.0        66.0
# 3    LP001006             2583             2358.0       120.0
# 4    LP001008             6000                0.0       141.0
# ..        ...              ...                ...         ...
# 609  LP002978             2900                0.0        71.0
# 610  LP002979             4106                0.0        40.0
# 611  LP002983             8072              240.0       253.0
# 612  LP002984             7583                0.0       187.0
# 613  LP002990             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History  Gender_Male  Married_Yes  Dependents_1  \
# 0               360.0             1.0            1            0             0
# ...

# %%
data_hot=data_hot.drop(columns='Loan_ID')
data_hot
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         0.0             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History  Gender_Male  Married_Yes  Dependents_1  Dependents_2  \
# ...

# %%
feature_names=data_hot.columns

# %%
data_new = data_hot.drop("Loan_Status_Y", axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(data_new, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.6168831168831169

# %%
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.7142857142857143

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.2194243007437424, 'ApplicantIncome'),
#  (0.2034652865443047, 'LoanAmount'),
#  (0.15722210760732266, 'Credit_History'),
#  (0.12839168385053207, 'CoapplicantIncome'),
#  (0.057530846971704165, 'Loan_Amount_Term'),
#  (0.03428650191013079, 'Property_Area_Semiurban'),
#  (0.030798558132043047, 'Gender_Male'),
#  (0.030672985392094475, 'Married_Yes'),
#  (0.028211622815506647, 'Education_Not Graduate'),
#  (0.026241554942293275, 'Dependents_1'),
#  (0.026216560348838024, 'Property_Area_Urban'),
#  (0.0209706773674195, 'Self_Employed_Yes'),
#  (0.020753216158269458, 'Dependents_2'),
#  (0.015814097215798507, 'Dependents_3+')]
